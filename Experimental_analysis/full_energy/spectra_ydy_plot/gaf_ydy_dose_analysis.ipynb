# %% [markdown]
# ### This script is used to calculate mean values and errors of yf_exp and yd_exp from csv files obtained

# %%
#importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#function to calculate the mean of every column

def mean_values(data):
    for i in data.columns:
        print(i,":",data[i].mean())

# %%
#make a function to find standard deviation of each column
def std_values(data):
    for i in data.columns:
        print(i, data[i].std())

# %%
#store mean values and std values in dataframes
def mean_std_yf_yd(data):
    mean_values(data)
    std_values(data)
    mean = pd.DataFrame(data.mean())
    std = pd.DataFrame(data.std())
    mean_std = pd.concat([mean, std], axis=1)
    mean_std.columns = ['Mean of yf', 'standard deviation of yf', 'Mean of yd', 'standard deviation of yd']
    return mean_std_yf_yd

# %%
#gaf_0
gaf_0 = pd.read_csv('spectra_gaf_0.csv', header=None, delimiter='\t')
gaf_0 = pd.DataFrame({'yf': gaf_0[0], 'yd': gaf_0[1]})

# %%
gaf_1=pd.read_csv('spectra_gaf_1.csv', header=None, delimiter=' ')
gaf_1=pd.DataFrame({'yf':gaf_1[0], 'yd':gaf_1[1]})

# %%
yf = []
yd = []
with open('spectra_gaf_2.csv') as f:
    for line in f:
        gaf_2 = line.strip().split()
        yf.append(float(gaf_2[0]))
        yd.append(float(gaf_2[1]))
gaf_2 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_3.csv') as f:
    for line in f:
        gaf_3 = line.strip().split()
        yf.append(float(gaf_3[0]))
        yd.append(float(gaf_3[1]))
gaf_3 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_4.csv') as f:
    for line in f:
        gaf_4 = line.strip().split()
        yf.append(float(gaf_4[0]))
        yd.append(float(gaf_4[1]))
gaf_4 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_5.csv') as f:
    for line in f:
        gaf_5 = line.strip().split()
        yf.append(float(gaf_5[0]))
        yd.append(float(gaf_5[1]))
gaf_5 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_6.csv') as f:
    for line in f:
        gaf_6 = line.strip().split()
        yf.append(float(gaf_6[0]))
        yd.append(float(gaf_6[1]))
gaf_6 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_7.csv') as f:
    for line in f:
        gaf_7 = line.strip().split()
        yf.append(float(gaf_7[0]))
        yd.append(float(gaf_7[1]))
gaf_7 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_8.csv') as f:
    for line in f:
        gaf_8 = line.strip().split()
        yf.append(float(gaf_8[0]))
        yd.append(float(gaf_8[1]))
gaf_8 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_9.csv') as f:
    for line in f:
        gaf_9 = line.strip().split()
        yf.append(float(gaf_9[0]))
        yd.append(float(gaf_9[1]))
gaf_9 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_10.csv') as f:
    for line in f:
        gaf_10 = line.strip().split()
        yf.append(float(gaf_10[0]))
        yd.append(float(gaf_10[1]))
gaf_10 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_11.csv') as f:
    for line in f:
        gaf_11 = line.strip().split()
        yf.append(float(gaf_11[0]))
        yd.append(float(gaf_11[1]))
gaf_11 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_12.csv') as f:
    for line in f:
        gaf_12 = line.strip().split()
        yf.append(float(gaf_12[0]))
        yd.append(float(gaf_12[1]))
gaf_12 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_13.csv') as f:
    for line in f:
        gaf_13 = line.strip().split()
        yf.append(float(gaf_13[0]))
        yd.append(float(gaf_13[1]))
gaf_13 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_14.csv') as f:
    for line in f:
        gaf_14 = line.strip().split()
        yf.append(float(gaf_14[0]))
        yd.append(float(gaf_14[1]))
gaf_14 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_15.csv') as f:
    for line in f:
        gaf_15 = line.strip().split()
        yf.append(float(gaf_15[0]))
        yd.append(float(gaf_15[1]))
gaf_15 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_16.csv') as f:
    for line in f:
        gaf_16 = line.strip().split()
        yf.append(float(gaf_16[0]))
        yd.append(float(gaf_16[1]))
gaf_16 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_17.csv') as f:
    for line in f:
        gaf_17 = line.strip().split()
        yf.append(float(gaf_17[0]))
        yd.append(float(gaf_17[1]))
gaf_17 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_18.csv') as f:
    for line in f:
        gaf_18 = line.strip().split()
        yf.append(float(gaf_18[0]))
        yd.append(float(gaf_18[1]))
gaf_18 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
yf = []
yd = []
with open('spectra_gaf_19.csv') as f:
    for line in f:
        gaf_19 = line.strip().split()
        yf.append(float(gaf_19[0]))
        yd.append(float(gaf_19[1]))
gaf_19 = pd.DataFrame({'yf': yf, 'yd': yd})

# %%
import pandas as pd

# Create an empty list to store the dataframes
gaf_list = []

# Loop over the file numbers
for i in range(1, 20):
    # Open the file and read the data
    with open(f'spectra_gaf_{i}.csv') as f:
        y = []
        ydy = []
        for line in f:
            gaf = line.strip().split()
            y.append(float(gaf[0]))
            ydy.append(float(gaf[1]))
    # Create a dataframe and append it to the list
    gaf_df = pd.DataFrame({'gaf': f'gaf_{i}', 'y': yf, 'ydy': yd})
    gaf_list.append(gaf_df)

# Concatenate the dataframes in the list into a single dataframe
gaf_all = pd.concat(gaf_list, axis=0, ignore_index=True)

# Print the data for each gaf
for i in range(0, 21):
    gaf_data = gaf_all[gaf_all['gaf'] == f'gaf_{i}']
    print(f'gaf_{i}:')
    print(gaf_data[['y', 'ydy']])
# Out:
# gaf_0:
# Empty DataFrame
# Columns: [y, ydy]
# Index: []
# gaf_1:
#                 y  ydy
# 0       -0.002900  0.0
# 1        0.165313  0.0
# 2        0.333527  0.0
# 3        0.501740  0.0
# 4        0.669954  0.0
# ...           ...  ...
# 8187  1377.160673  0.0
# 8188  1377.328886  0.0
# 8189  1377.497100  0.0
# 8190  1377.665313  0.0
# 8191  1377.833527  0.0
#
# [8192 rows x 2 columns]
# gaf_2:
#                  y  ydy
# 8192     -0.002900  0.0
# 8193      0.165313  0.0
# 8194      0.333527  0.0
# 8195      0.501740  0.0
# 8196      0.669954  0.0
# ...            ...  ...
# 16379  1377.160673  0.0
# 16380  1377.328886  0.0
# 16381  1377.497100  0.0
# 16382  1377.665313  0.0
# 16383  1377.833527  0.0
#
# [8192 rows x 2 columns]
# gaf_3:
#                  y  ydy
# 16384    -0.002900  0.0
# 16385     0.165313  0.0
# 16386     0.333527  0.0
# 16387     0.501740  0.0
# 16388     0.669954  0.0
# ...            ...  ...
# 24571  1377.160673  0.0
# 24572  1377.328886  0.0
# ...

# %%
gaf_mean_y = gaf_all.groupby('gaf')['y'].mean()
#print('Mean of y for each GAF:')

#print('====================================')
#print('***************GAF_1****************')

# %%
data = pd.read_excel('dose_oxygenmac_no_secondary.ods', header = 0)
data.columns = ['Depth', 'Dose']
data
# Out:
#      Depth          Dose
# 0        0  2.009040e-05
# 1        1  2.014640e-05
# 2        2  2.023010e-05
# 3        3  2.037560e-05
# 4        4  2.050520e-05
# ..     ...           ...
# 395    395  6.056530e-09
# 396    396  6.466210e-09
# 397    397  7.165070e-09
# 398    398  5.377830e-09
# 399    399  5.369630e-09
#
# [400 rows x 2 columns]

# %%
data1 = pd.read_excel('exp.ods', header = None)
data1.columns = ['Depth', 'Dose'] 
data1
# Out:
#     Depth      Dose
# 0   2.250  1.579136
# 1   2.498  1.615597
# 2   2.751  1.670083
# 3   2.998  1.688262
# 4   3.250  1.784016
# 5   3.499  1.860304
# 6   3.748  1.850847
# 7   3.997  1.941559
# 8   4.247  2.069230
# 9   4.495  2.173762
# 10  4.747  2.338305
# 11  4.997  2.494489
# 12  5.247  2.695163
# 13  5.499  2.952033
# 14  5.749  3.309446
# 15  5.998  3.959701
# 16  6.245  5.237302
# 17  6.532  9.944636
# 18  6.748  0.045075
# 19  7.000  0.032068
# 20  7.249  0.026153
# 21  7.501  0.021149
# 22  7.749  0.016266
# 23  7.998  0.007212
# 24  8.246  0.010509
# 25  8.497  0.008377
# 26  8.744  0.004183

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111, label="1")
ax2 = fig.add_subplot(111, label="2", frame_on=False)

ax1.plot(gaf_1['yf'], gaf_1['yd'], linestyle='solid', color='blue', linewidth=0.91, label='0.355mm')
ax1.plot(gaf_2['yf'], gaf_2['yd'], linestyle='solid',color='orange', linewidth=0.91, label='0.71 mm')
ax1.plot(gaf_3['yf'], gaf_3['yd'], linestyle='solid', color='yellow', linewidth=0.91, label='1.07 mm')
ax1.plot(gaf_4['yf'], gaf_4['yd'], linestyle='solid', color='black', linewidth=0.91, label='1.43 mm')
ax1.plot(gaf_5['yf'], gaf_5['yd'], linestyle='solid', color='cyan', linewidth=0.91, label='1.79 mm')
ax1.plot(gaf_6['yf'], gaf_6['yd'], linestyle='solid', color='green', linewidth=0.94, label='2.13 mm')
ax1.plot(gaf_7['yf'], gaf_7['yd'], linestyle='solid', color='pink', linewidth=0.94, label='2.49 mm')
ax1.plot(gaf_8['yf'], gaf_8['yd'], linestyle='solid', color='red', linewidth=0.94, label='2.84 mm')
ax1.plot(gaf_9['yf'], gaf_9['yd'], linestyle='solid', color='darkblue', linewidth=0.94, label='3.20 mm')
ax1.plot(gaf_10['yf'], gaf_10['yd'], linestyle='solid', color='purple', linewidth=0.94, label='3.55 mm')
ax1.plot(gaf_11['yf'], gaf_11['yd'], linestyle='solid', color='darkgreen', linewidth=0.94, label='3.91 mm')
ax1.plot(gaf_12['yf'], gaf_12['yd'], linestyle='solid', color='brown', linewidth=0.91, label='4.26 mm')
ax1.plot(gaf_13['yf'], gaf_13['yd'], linestyle='solid', color='darkred', linewidth=0.91, label='4.62 mm')
ax1.plot(gaf_14['yf'], gaf_14['yd'], linestyle='solid', color='magenta', linewidth=0.91, label='4.97 mm')
ax1.plot(gaf_15['yf'], gaf_15['yd'], linestyle='solid', color='darkcyan', linewidth=0.91, label='5.33 mm')
ax1.plot(gaf_16['yf'], gaf_16['yd'], linestyle='solid', color='gray',linewidth=0.91, label='5.68 mm')
ax1.plot(gaf_17['yf'], gaf_17['yd'], linestyle='solid', color='olive', linewidth=0.91, label='6.035 mm')
ax1.plot(gaf_18['yf'], gaf_18['yd'], linestyle='solid', color='darkmagenta', linewidth=0.91, label='6.39 mm')
ax1.plot(gaf_19['yf'], gaf_19['yd'], linestyle='solid', color='darkgray', linewidth=0.91, label='6.75 mm')

ax1.set_xlabel('y [KeV/um]')
ax1.set_ylabel('yd(y) [a.u.]')


ax1.xaxis.tick_bottom()
ax1.yaxis.tick_left()
ax1.xaxis.set_label_position('bottom')
ax1.yaxis.set_label_position('left')
ax1.set_xlim(0, 400)
ax1.set_ylim(0, 20)


ax2.plot(data['Depth']/10, data['Dose']/data['Dose'].max(), color='gray', linewidth=2.1, alpha=0.5, label='Simulation')
ax2.scatter(data1['Depth'], data1['Dose']/data1['Dose'].max(), marker='o', facecolors='black', edgecolors='black', s=10, label='Measurement')


ax2.patch.set_alpha(0.5)


ax2.set_xlabel('Depth [mm]')
ax2.set_ylabel('Dose [a.u.]')

ax2.xaxis.tick_top()
ax2.yaxis.tick_right()
ax2.xaxis.set_label_position('top')
ax2.yaxis.set_label_position('right')
ax2.set_xlim(0, 7)


depths = [0.355, 0.71, 1.065, 1.42, 1.775, 2.13, 2.485, 2.84, 3.195, 3.55, 3.905, 4.26, 4.615, 4.97, 5.325, 5.68, 6.035, 6.39, 6.75]

#depths = [0.355, 0.71, 2.13, 2.84, 3.55, 4.26, 4.97, 5.68, 6.035] # the depths where you want to add markers
depths = np.array(depths)
facecolors=['blue', 'orange', 'yellow', 'black', 'cyan', 'green', 'pink', 'red', 'darkblue', 'purple', 'darkgreen', 'brown', 'darkred', 'magenta', 'darkcyan', 'gray', 'olive', 'darkmagenta', 'darkgray']
# Get the y-axis position for each depth
for depth in depths:
    y_pos = np.interp(depths, data['Depth']/10, data['Dose']/data['Dose'].max())
    #plot the markers
    ax2.scatter(depths, y_pos, marker='s', facecolors=facecolors, edgecolors=facecolors, s=20)
    #use colors from the yd(y) plot


# Move legends outside the plot
ax1.legend(loc='upper right', bbox_to_anchor=(-0.13, 1), borderaxespad=0)
ax2.legend(loc='upper left', bbox_to_anchor=(1.07, 1), borderaxespad=0)
plt.show()

# %%
y = []
ydy = []
c=[]
d=[]
with open('spectra_rebin_gaf_2.csv') as f:
    for line in f:
        gaf_2_rebin = line.strip().split()
        y.append(float(gaf_2_rebin[0]))
        ydy.append(float(gaf_2_rebin[1]))
        c.append(float(gaf_2_rebin[2]))

        d.append(float(gaf_2_rebin[3]))

gaf_2_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'c': c, 'ydy_normwidth': d})

# %%
y = []
ydy = []
c=[]
d=[]
with open('spectra_rebin_gaf_3.csv') as f:
    for line in f:
        gaf_3_rebin = line.strip().split()
        y.append(float(gaf_3_rebin[0]))
        ydy.append(float(gaf_3_rebin[1]))
        c.append(float(gaf_3_rebin[2]))

        d.append(float(gaf_3_rebin[3]))

gaf_3_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y = []
ydy = []
c=[]
d=[]
with open('spectra_rebin_gaf_4.csv') as f:
    for line in f:
        gaf_4_rebin = line.strip().split()
        y.append(float(gaf_4_rebin[0]))
        ydy.append(float(gaf_4_rebin[1]))
        c.append(float(gaf_4_rebin[2]))

        d.append(float(gaf_4_rebin[3]))

gaf_4_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y = []
ydy = []
c=[]
d=[]

with open('spectra_rebin_gaf_5.csv') as f:
    for line in f:
        gaf_5_rebin = line.strip().split()
        y.append(float(gaf_5_rebin[0]))
        ydy.append(float(gaf_5_rebin[1]))
        c.append(float(gaf_5_rebin[2]))

        d.append(float(gaf_5_rebin[3]))

gaf_5_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
#READ spectra rebin file

y = []
ydy = []
c=[]
d=[]
with open('spectra_rebin_gaf_6.csv') as f:
    for line in f:
        gaf_6_rebin = line.strip().split()
        y.append(float(gaf_6_rebin[0]))
        ydy.append(float(gaf_6_rebin[1]))
        c.append(float(gaf_6_rebin[2]))

        d.append(float(gaf_6_rebin[3]))

gaf_6_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y = []
ydy = []
c=[]
d=[]
with open('spectra_rebin_gaf_7.csv') as f:
    
    for line in f:
        gaf_7_rebin = line.strip().split()
        y.append(float(gaf_7_rebin[0]))
        ydy.append(float(gaf_7_rebin[1]))
        c.append(float(gaf_7_rebin[2]))

        d.append(float(gaf_7_rebin[3]))

gaf_7_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y = []
ydy = []
c=[]
d=[]
with open('spectra_rebin_gaf_9.csv') as f:
    for line in f:
        gaf_9_rebin = line.strip().split()
        y.append(float(gaf_9_rebin[0]))
        ydy.append(float(gaf_9_rebin[1]))
        c.append(float(gaf_9_rebin[2]))

        d.append(float(gaf_9_rebin[3]))

gaf_9_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y = []
ydy = []
c=[]
d=[]
with open('spectra_rebin_gaf_10.csv') as f:
    for line in f:
        gaf_10_rebin = line.strip().split()
        y.append(float(gaf_10_rebin[0]))
        ydy.append(float(gaf_10_rebin[1]))
        c.append(float(gaf_10_rebin[2]))

        d.append(float(gaf_10_rebin[3]))

gaf_10_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y=[]
ydy=[]
c=[]
d=[]
with open('spectra_rebin_gaf_11.csv') as f:
    for line in f:
        gaf_11_rebin = line.strip().split()
        y.append(float(gaf_11_rebin[0]))
        ydy.append(float(gaf_11_rebin[1]))
        c.append(float(gaf_11_rebin[2]))

        d.append(float(gaf_11_rebin[3]))

gaf_11_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y= []
ydy = []
c=[]
d=[]
with open('spectra_rebin_gaf_12.csv') as f:
    for line in f:
        gaf_12_rebin = line.strip().split()
        y.append(float(gaf_12_rebin[0]))
        ydy.append(float(gaf_12_rebin[1]))
        c.append(float(gaf_12_rebin[2]))

        d.append(float(gaf_12_rebin[3]))

gaf_12_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y=[]
ydy=[]
c=[]
d=[]

with open('spectra_rebin_gaf_13.csv') as f:

    for line in f:
        gaf_13_rebin = line.strip().split()
        y.append(float(gaf_13_rebin[0]))
        ydy.append(float(gaf_13_rebin[1]))
        c.append(float(gaf_13_rebin[2]))

        d.append(float(gaf_13_rebin[3]))

gaf_13_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y=[]
ydy=[]
c=[]
d=[]

with open('spectra_rebin_gaf_14.csv') as f:
    
    for line in f:
        gaf_14_rebin = line.strip().split()
        y.append(float(gaf_14_rebin[0]))
        ydy.append(float(gaf_14_rebin[1]))
        c.append(float(gaf_14_rebin[2]))

        d.append(float(gaf_14_rebin[3]))

gaf_14_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y=[]
ydy=[]
c=[]
d=[]

with open('spectra_rebin_gaf_15.csv') as f:
        
        for line in f:
            gaf_15_rebin = line.strip().split()
            y.append(float(gaf_15_rebin[0]))
            ydy.append(float(gaf_15_rebin[1]))
            c.append(float(gaf_15_rebin[2]))
    
            d.append(float(gaf_15_rebin[3]))

gaf_15_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y=[]
ydy=[]
c=[]
d=[]
with open('spectra_rebin_gaf_16.csv') as f:

    for line in f:
        gaf_16_rebin = line.strip().split()
        y.append(float(gaf_16_rebin[0]))
        ydy.append(float(gaf_16_rebin[1]))
        c.append(float(gaf_16_rebin[2]))

        d.append(float(gaf_16_rebin[3]))

gaf_16_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y=[]

ydy=[]
c=[]
d=[]

with open('spectra_rebin_gaf_17.csv') as f:
    
        for line in f:
            gaf_17_rebin = line.strip().split()
            y.append(float(gaf_17_rebin[0]))
            ydy.append(float(gaf_17_rebin[1]))
            c.append(float(gaf_17_rebin[2]))
    
            d.append(float(gaf_17_rebin[3]))

gaf_17_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y=[]
ydy=[]
c=[]
d=[]
with open('spectra_rebin_gaf_18.csv') as f:
        
        for line in f:
            gaf_18_rebin = line.strip().split()
            y.append(float(gaf_18_rebin[0]))
            ydy.append(float(gaf_18_rebin[1]))
            c.append(float(gaf_18_rebin[2]))
    
            d.append(float(gaf_18_rebin[3]))

gaf_18_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y=[]
ydy=[]
c=[]
d=[]
with open('spectra_rebin_gaf_19.csv') as f:

    for line in f:
        gaf_19_rebin = line.strip().split()
        y.append(float(gaf_19_rebin[0]))
        ydy.append(float(gaf_19_rebin[1]))
        c.append(float(gaf_19_rebin[2]))

        d.append(float(gaf_19_rebin[3]))

gaf_19_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y=[]
ydy=[]
c=[]
d=[]
with open('spectra_rebin_gaf_1.csv') as f:

    for line in f:
        gaf_1_rebin = line.strip().split()
        y.append(float(gaf_1_rebin[0]))
        ydy.append(float(gaf_1_rebin[1]))
        c.append(float(gaf_1_rebin[2]))

        d.append(float(gaf_1_rebin[3]))

gaf_1_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y=[]
ydy=[]
c=[]
d=[]
with open('spectra_rebin_gaf_0.csv') as f:

    for line in f:
        gaf_0_rebin = line.strip().split()
        y.append(float(gaf_0_rebin[0]))
        ydy.append(float(gaf_0_rebin[1]))
        c.append(float(gaf_0_rebin[2]))

        d.append(float(gaf_0_rebin[3]))

gaf_0_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
y=[]
ydy=[]
c=[]
d=[]
with open('spectra_rebin_gaf_8.csv') as f:

    for line in f:
        gaf_8_rebin = line.strip().split()
        y.append(float(gaf_8_rebin[0]))
        ydy.append(float(gaf_8_rebin[1]))
        c.append(float(gaf_8_rebin[2]))

        d.append(float(gaf_8_rebin[3]))

gaf_8_rebin = pd.DataFrame({'y': y, 'yd(y)': ydy, 'y_log': c, 'ydy_normwidth': d})

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111, label="1")
ax2 = fig.add_subplot(111, label="2", frame_on=False)

ax2.patch.set_alpha(1)


#ax1.plot(gaf_0_rebin['y'], gaf_0_rebin['ydy_normwidth'], color='blue', linewidth=2.1, alpha=0.5, label='0.00')
ax1.plot(gaf_1_rebin['y'], gaf_1_rebin['ydy_normwidth'], color='blue', label='0.355')
ax1.plot(gaf_2_rebin['y'], gaf_2_rebin['ydy_normwidth'], color='orange',  label='0.71')
ax1.plot(gaf_3_rebin['y'], gaf_3_rebin['ydy_normwidth'], color='yellow', label='1.065')
ax1.plot(gaf_4_rebin['y'], gaf_4_rebin['ydy_normwidth'], color='black',  label='1.42')
ax1.plot(gaf_5_rebin['y'], gaf_5_rebin['ydy_normwidth'], color='cyan', label='1.775')
ax1.plot(gaf_6_rebin['y'], gaf_6_rebin['ydy_normwidth'], color='green',  label='2.13')
ax1.plot(gaf_7_rebin['y'], gaf_7_rebin['ydy_normwidth'], color='pink',  label='2.485')
ax1.plot(gaf_8_rebin['y'], gaf_8_rebin['ydy_normwidth'], color='red', label='2.84')
ax1.plot(gaf_9_rebin['y'], gaf_9_rebin['ydy_normwidth'], color='darkblue',  label='3.195')
ax1.plot(gaf_10_rebin['y'], gaf_10_rebin['ydy_normwidth'], color='purple', label='3.55')
ax1.plot(gaf_11_rebin['y'], gaf_11_rebin['ydy_normwidth'], color='darkgreen', label='3.905')
ax1.plot(gaf_12_rebin['y'], gaf_12_rebin['ydy_normwidth'], color='brown', label='4.26')
ax1.plot(gaf_13_rebin['y'], gaf_13_rebin['ydy_normwidth'], color='darkred',  label='4.615')
ax1.plot(gaf_14_rebin['y'], gaf_14_rebin['ydy_normwidth'], color='magenta',  label='4.97')
ax1.plot(gaf_15_rebin['y'], gaf_15_rebin['ydy_normwidth'], color='darkcyan', label='5.325')
ax1.plot(gaf_16_rebin['y'], gaf_16_rebin['ydy_normwidth'], color='gray', label='5.68')
ax1.plot(gaf_17_rebin['y'], gaf_17_rebin['ydy_normwidth'], color='olive', label='6.035')
ax1.plot(gaf_18_rebin['y'], gaf_18_rebin['ydy_normwidth'], color='darkmagenta',  label='6.39')
ax1.plot(gaf_19_rebin['y'], gaf_19_rebin['ydy_normwidth'], color='darkgray',  label='6.745')

ax1.set_xlabel('y [KeV/um]')
ax1.set_ylabel('yd(y) [a.u.]')


ax1.xaxis.tick_bottom()
ax1.yaxis.tick_left()
ax1.xaxis.set_label_position('bottom')
ax1.yaxis.set_label_position('left')
#log scale
ax1.set_xscale('log')
ax1.set_xlim(50, 600)
ax1.set_ylim(0, 190)


ax2.plot(data['Depth']/10, data['Dose']/data['Dose'].max(), color='gray', linewidth=2.1, alpha=0.5, label='Simulation')
ax2.scatter(data1['Depth'], data1['Dose']/data1['Dose'].max(), marker='o', facecolors='black', edgecolors='black', s=10, label='Measurement')


ax2.patch.set_alpha(0.5)


ax2.set_xlabel('Depth [mm]')
ax2.set_ylabel('Dose [a.u.]')

ax2.xaxis.tick_top()
ax2.yaxis.tick_right()
ax2.xaxis.set_label_position('top')
ax2.yaxis.set_label_position('right')
ax2.set_xlim(0, 7)


depths = [0.355, 0.71, 1.065, 1.42, 1.775, 2.13, 2.485, 2.84, 3.195, 3.55, 3.905, 4.26, 4.615, 4.97, 5.325, 5.68, 6.035, 6.39, 6.75]

#depths = [0.355, 0.71, 2.13, 2.84, 3.55, 4.26, 4.97, 5.68, 6.035] # the depths where you want to add markers
depths = np.array(depths)
facecolors=['blue', 'orange', 'yellow', 'black', 'cyan', 'green', 'pink', 'red', 'darkblue', 'purple', 'darkgreen', 'brown', 'darkred', 'magenta', 'darkcyan', 'gray', 'olive', 'darkmagenta', 'darkgray']
# Get the y-axis position for each depth
for depth in depths:
    y_pos = np.interp(depths, data['Depth']/10, data['Dose']/data['Dose'].max())
    #plot the markers
    ax2.scatter(depths, y_pos, marker='s', facecolors=facecolors, edgecolors=facecolors, s=20)
    #use colors from the yd(y) plot


# Move legends outside the plot
ax1.legend(loc='upper right', bbox_to_anchor=(-0.13, 1), borderaxespad=0)
ax2.legend(loc='upper left', bbox_to_anchor=(1.07, 1), borderaxespad=0)
plt.show()
